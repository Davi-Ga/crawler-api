# %%
import pandas as pd
teste = pd.read_json("./data.json")
teste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122557 entries, 0 to 122556
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   proposicao            122557 non-null  object
#  1   autor                 116929 non-null  object
#  2   political_party       102888 non-null  object
#  3   relator               5628 non-null    object
#  4   proposicao_principal  5523 non-null    object
# dtypes: object(5)
# memory usage: 5.6+ MB

# %%
import pandas as pd
import json

teste = pd.read_json("./data.json")
teste["autor"] = teste["autor"].fillna("placeholder")
teste["autor"] = teste.apply(lambda row: row["relator"] if row["autor"] == "placeholder" else row["autor"], axis=1)
json_object = json.loads('{"ementa": "vazio"}')
# Replace null values in the "proposicao_principal" column with a placeholder value
teste["proposicao_principal"] = teste["proposicao_principal"].fillna("placeholder")
teste["proposicao_principal"] = teste["proposicao_principal"].apply(lambda x: json_object if x == "placeholder" else x)

teste = teste.drop(columns=["relator"])
teste["proposicao"] = teste["proposicao"].drop_duplicates()

# %%
teste = teste.dropna()

# %%
teste["political_party"]
# Out:
# 0        {'nome': 'Partido da República', 'sigla': 'PR'...
# 1        {'nome': 'Partido da República', 'sigla': 'PR'...
# 2        {'nome': 'Partido Socialismo e Liberdade', 'si...
# 3        {'nome': 'Partido Socialismo e Liberdade', 'si...
# 4        {'nome': 'Partido Socialismo e Liberdade', 'si...
#                                ...
# 69416    {'nome': 'Partido Social Democrático', 'sigla'...
# 69417    {'nome': 'Republicanos', 'sigla': 'REPUBLICANO...
# 69418    {'nome': 'Republicanos', 'sigla': 'REPUBLICANO...
# 69419    {'nome': 'Republicanos', 'sigla': 'REPUBLICANO...
# 69420    {'nome': 'Republicanos', 'sigla': 'REPUBLICANO...
# Name: political_party, Length: 12538, dtype: object

# %%
proposicao = pd.json_normalize(teste["proposicao"], max_level=1)
autor = pd.json_normalize(teste["autor"], max_level=1)
proposicao_principal = pd.json_normalize(teste["proposicao_principal"], max_level=1)
political_party = pd.json_normalize(teste["political_party"], max_level=1)
political_party = political_party.rename(columns={"nome": 'nome_partido', 'sigla': "sigla_partido", 'status': 'status_partido', 'total_membros': 'total_membros_partido'})

# %%
dataset = pd.concat([ proposicao, autor, proposicao_principal, political_party], axis=1)

# %%
dataset
# Out:
#                                                   ementa  \
# 0      Dispõe sobre a obrigatoriedade de fotografia n...
# 1      Garante ao acertador de qualquer tipo de jogo ...
# 2      Dispõe sobre a obrigatoriedade das prestadoras...
# 3      Institui o dia 02 de julho como data histórica...
# 4      Regulamenta o § 7º do art. 37 da Constituição ...
# ...                                                  ...
# 12533  Altera a Lei nº 8.069, de 13 de julho de 1990 ...
# 12534                 Parecer exarado no RIC n. 296/2024
# 12535                 Parecer exarado no RIC n. 274/2024
# 12536                 Parecer exarado no RIC n. 284/2024
# 12537                 Parecer exarado no RIC n. 290/2024
#
#                                          ementaDetalhada   ano  \
# 0       Altera a Lei nº 7.444 de 20 de dezembro de 1985.  2003
# 1                                                         2003
# 2                                                         2003
# ...

# %%
dataset["nome"]
# Out:
# 0              CARLOS FREDERICO THEODORO NADER
# 1                       ANDRES NAVARRO SANCHEZ
# 2         FRANCISCO RODRIGUES DE ALENCAR FILHO
# 3                      DOUGLAS DE PAULO VIEGAS
# 4                        GILSON MARQUES VIEIRA
#                          ...
# 12533    MARIA LAURA MONTEZA DE SOUZA CARNEIRO
# 12534                   MARCOS ANTONIO PEREIRA
# 12535                   MARCOS ANTONIO PEREIRA
# 12536                   MARCOS ANTONIO PEREIRA
# 12537                   MARCOS ANTONIO PEREIRA
# Name: nome, Length: 12538, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12538 entries, 0 to 12537
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ementa                 12538 non-null  object
#  1   ementaDetalhada        6598 non-null   object
#  2   ano                    12538 non-null  int64
#  3   keywords               6596 non-null   object
#  4   uris.uriAutores        12538 non-null  object
#  5   uris.uriPropPrincipal  2334 non-null   object
#  6   uris.uriUltimoRelator  3688 non-null   object
#  7   nome                   12538 non-null  object
#  8   cpf                    12538 non-null  object
#  9   foto                   12538 non-null  object
#  10  sexo                   12538 non-null  object
#  11  nascimento             12538 non-null  object
#  12  local_nascimento       12538 non-null  object
#  13  escolaridade           12228 non-null  object
# ...

# %%
dataset["nome"]
# Out:
# 0              CARLOS FREDERICO THEODORO NADER
# 1                       ANDRES NAVARRO SANCHEZ
# 2         FRANCISCO RODRIGUES DE ALENCAR FILHO
# 3                      DOUGLAS DE PAULO VIEGAS
# 4                        GILSON MARQUES VIEIRA
#                          ...
# 12533    MARIA LAURA MONTEZA DE SOUZA CARNEIRO
# 12534                   MARCOS ANTONIO PEREIRA
# 12535                   MARCOS ANTONIO PEREIRA
# 12536                   MARCOS ANTONIO PEREIRA
# 12537                   MARCOS ANTONIO PEREIRA
# Name: nome, Length: 12538, dtype: object

# %%
cand1 = pd.read_csv("consulta_cand_2000_BRASIL.csv", encoding="latin-1", delimiter=";")
cand2 = pd.read_csv("consulta_cand_2002_BRASIL.csv", encoding="latin-1", delimiter=";")
cand3 = pd.read_csv("consulta_cand_2004_BRASIL.csv", encoding="latin-1", delimiter=";")
cand4 = pd.read_csv("consulta_cand_2006_BRASIL.csv", encoding="latin-1", delimiter=";")
cand5 = pd.read_csv("consulta_cand_2008_BRASIL.csv", encoding="latin-1", delimiter=";")
cand6 = pd.read_csv("consulta_cand_2010_BRASIL.csv", encoding="latin-1", delimiter=";")
cand7 = pd.read_csv("consulta_cand_2012_BRASIL.csv", encoding="latin-1", delimiter=";")

cand8 = pd.read_csv("consulta_cand_2014_BRASIL.csv", encoding="latin-1", delimiter=";")
cand9 = pd.read_csv("consulta_cand_2016_BRASIL.csv", encoding="latin-1", delimiter=";")
cand10 = pd.read_csv("consulta_cand_2018_BRASIL.csv", encoding="latin-1", delimiter=";")
cand11 = pd.read_csv("consulta_cand_2020_BRASIL.csv", encoding="latin-1", delimiter=";")
cand12 = pd.read_csv("consulta_cand_2022_BRASIL.csv", encoding="latin-1", delimiter=";")

candidatos = pd.concat([cand1, cand2, cand3, cand4, cand5, cand6, cand7, cand8, cand9,cand10,cand11,cand12,])
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_22612\2924868582.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   cand1 = pd.read_csv("consulta_cand_2000_BRASIL.csv", encoding="latin-1", delimiter=";")
# C:\Users\alexa\AppData\Local\Temp\ipykernel_22612\2924868582.py:3: DtypeWarning: Columns (20,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   cand3 = pd.read_csv("consulta_cand_2004_BRASIL.csv", encoding="latin-1", delimiter=";")
# C:\Users\alexa\AppData\Local\Temp\ipykernel_22612\2924868582.py:7: DtypeWarning: Columns (57) have mixed types. Specify dtype option on import or set low_memory=False.
#   cand7 = pd.read_csv("consulta_cand_2012_BRASIL.csv", encoding="latin-1", delimiter=";")
# C:\Users\alexa\AppData\Local\Temp\ipykernel_22612\2924868582.py:9: DtypeWarning: Columns (57) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
candidatos = candidatos.drop_duplicates(subset=["NM_CANDIDATO"]).reset_index(drop=True)
candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1813433 entries, 0 to 1813432
# Data columns (total 75 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   DT_GERACAO                     object
#  1   HH_GERACAO                     object
#  2   ANO_ELEICAO                    int64
#  3   CD_TIPO_ELEICAO                int64
#  4   NM_TIPO_ELEICAO                object
#  5   NR_TURNO                       int64
#  6   CD_ELEICAO                     int64
#  7   DS_ELEICAO                     object
#  8   DT_ELEICAO                     object
#  9   TP_ABRANGENCIA                 object
#  10  SG_UF                          object
#  11  SG_UE                          object
#  12  NM_UE                          object
#  13  CD_CARGO                       int64
#  14  DS_CARGO                       object
#  15  SQ_CANDIDATO                   int64
#  16  NR_CANDIDATO                   int64
# ...

# %%
nome = candidatos["NM_CANDIDATO"].reset_index(drop=True)
cor = candidatos["DS_COR_RACA"].reset_index(drop=True)

# %%
candidato = pd.DataFrame()
candidato["nome"] = nome
candidato["cor"] = cor

# %%
candidato
# Out:
#                                                     nome     cor
# 0                                 PAULO RUCAS BRITO ACHY     #NE
# 1                                        EDEMIR DE SOUZA     #NE
# 2                                   WAGNER LUIS DO PRADO     #NE
# 3                                VALQUÍRIA DE LEMOS MELO     #NE
# 4                           ALVARO LUIZ BORTOLOTTO PREIS     #NE
# ...                                                  ...     ...
# 1813428                           MANOEL ANTÔNIO DE MELO   PARDA
# 1813429              SILVIA HELENA FREIRE DE PAIVA SOUZA  BRANCA
# 1813430                         JOSE SILVA MIGUEL JUNIOR  BRANCA
# 1813431                          ANGELINA REJANE DO VALE   PARDA
# 1813432  MARIÂNGELA FERDINANDA PEREIRA MARINHO RODRIGUES   PARDA
#
# [1813433 rows x 2 columns]

# %%
dataset2 = pd.merge(dataset, candidato, on="nome")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12538 entries, 0 to 12537
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ementa                 12538 non-null  object
#  1   ementaDetalhada        6598 non-null   object
#  2   ano                    12538 non-null  int64
#  3   keywords               6596 non-null   object
#  4   uris.uriAutores        12538 non-null  object
#  5   uris.uriPropPrincipal  2334 non-null   object
#  6   uris.uriUltimoRelator  3688 non-null   object
#  7   nome                   12538 non-null  object
#  8   cpf                    12538 non-null  object
#  9   foto                   12538 non-null  object
#  10  sexo                   12538 non-null  object
#  11  nascimento             12538 non-null  object
#  12  local_nascimento       12538 non-null  object
#  13  escolaridade           12228 non-null  object
# ...

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11737 entries, 0 to 11736
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ementa                 11737 non-null  object
#  1   ementaDetalhada        6292 non-null   object
#  2   ano                    11737 non-null  int64
#  3   keywords               6290 non-null   object
#  4   uris.uriAutores        11737 non-null  object
#  5   uris.uriPropPrincipal  2242 non-null   object
#  6   uris.uriUltimoRelator  3497 non-null   object
#  7   nome                   11737 non-null  object
#  8   cpf                    11737 non-null  object
#  9   foto                   11737 non-null  object
#  10  sexo                   11737 non-null  object
#  11  nascimento             11737 non-null  object
#  12  local_nascimento       11737 non-null  object
#  13  escolaridade           11471 non-null  object
# ...

# %%
dataset2.to_csv("./cor_da_justica.csv")
