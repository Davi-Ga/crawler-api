# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./cor_da_justica.csv")
df = df.drop(columns="Unnamed: 0", axis=1)

# %%
df = df.rename(columns={"ementa.1": "ementa_principal", "keywords.1": "keywords_principal"})

# %%
df.head(12)
# Out:
#                                                ementa  \
# 0   Dispõe sobre a obrigatoriedade de fotografia n...
# 1   Garante ao acertador de qualquer tipo de jogo ...
# 2   Dispõe sobre a obrigatoriedade das prestadoras...
# 3   Institui o dia 02 de julho como data histórica...
# 4   Altera o inciso I do § 1º do art. 68 da Lei nº...
# 5   Regulamenta o § 7º do art. 37 da Constituição ...
# 6   Estabelece prazo de impedimento para o ex-pres...
# 7   Altera dispositivos da Lei nº 9.648, de 27 de ...
# 8   Revigora a Lei nº 2.689, de 20 de Dezembro de ...
# 9   Dispõe sobre a relação discriminada de todas a...
# 10  Revoga o art. 70 da Lei nº 4.117, de 1962, ext...
# 11  Dispõe sobre a obrigatoriedade de as instituiç...
#
#                                       ementaDetalhada  \
# 0    Altera a Lei nº 7.444 de 20 de dezembro de 1985.
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Fixa um período de impedimento ou quarentena d...
# 6   Fixa o prazo de "quarentena" de um ano, a part...
# 7                                                 NaN
# 8   Restabelece a lei que denomina "Dois de Julho"...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
#                                              keywords  \
# 0   Alteração, Lei do Processamento Eletrônico do ...
# 1   Garantia, omissão, identificação, ganhador, lo...
# 2   Obrigatoriedade, concessionária, telefone celu...
# 3   Criação, Dia Nacional da Independência do Bras...
# 4   Alteração, Nova Lei de Patentes,  licenciament...
# 5   Regulamentação, Constituição Federal, requisit...
# 6   Regulamentação, Constituição Federal, fixação,...
# 7   Alteração, lei federal, aumento, percentual, c...
# 8   Restabelecimento, lei federal, denominação, Ae...
# 9   Obrigatoriedade, concessionária, telefonia, ap...
# 10  Alteração, Código Brasileiro de Telecomunicaçõ...
# 11  Obrigatoriedade, instituição financeira, banco...
#
#                                       uris.uriAutores  \
# 0   https://dadosabertos.camara.leg.br/api/v2/prop...
# 1   https://dadosabertos.camara.leg.br/api/v2/prop...
# 2   https://dadosabertos.camara.leg.br/api/v2/prop...
# 3   https://dadosabertos.camara.leg.br/api/v2/prop...
# 4   https://dadosabertos.camara.leg.br/api/v2/prop...
# 5   https://dadosabertos.camara.leg.br/api/v2/prop...
# 6   https://dadosabertos.camara.leg.br/api/v2/prop...
# 7   https://dadosabertos.camara.leg.br/api/v2/prop...
# 8   https://dadosabertos.camara.leg.br/api/v2/prop...
# 9   https://dadosabertos.camara.leg.br/api/v2/prop...
# 10  https://dadosabertos.camara.leg.br/api/v2/prop...
# 11  https://dadosabertos.camara.leg.br/api/v2/prop...
#
#                                 uris.uriPropPrincipal  \
# 0                                                 NaN
# 1   https://dadosabertos.camara.leg.br/api/v2/prop...
# 2   https://dadosabertos.camara.leg.br/api/v2/prop...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6
# 0             Barra Mansa - RJ             Superior
# 1                 Limeira - SP   Ensino Fundamental
# 2          Rio de Janeiro - RJ             Mestrado
# 3               São Paulo - SP                  NaN
# 4                Pocinhos - PB             Superior
# 5              Rio do Sul - SC        Pós-Graduação
# 6                Manhuaçu - MG             Superior
# 7            Santo Inácio - PR           Secundário
# 8        Feira de Santana - BA             Superior
# 9   Santa Maria do Suaçuí - MG             Superior
# 10               Teresina - PI  Superior Incompleto
# 11           Porto Alegre - RS        Pós-Graduação
#
#                                      ementa_principal            situacao  \
# 0                                               vazio                 NaN
# 1   Acrescenta art. 10-B à Lei n° 9.613, de 3 de m...  Aguardando Parecer
# 2   Altera o inciso IV do art. 3º da Lei nº 9.472,...  Aguardando Parecer
# 3                                               vazio                 NaN
# 4                                               vazio                 NaN
# 5                                               vazio                 NaN
# 6   Regulamenta o § 7º do art. 37 da Constituição ...  Aguardando Parecer
# 7                                               vazio                 NaN
# 8   Institui o dia 02 de julho como data histórica...  Aguardando Parecer
# 9   Altera o inciso IV do art. 3º da Lei nº 9.472,...  Aguardando Parecer
# 10                                              vazio                 NaN
# 11                                              vazio                 NaN
#
#               tipo                                 keywords_principal
# 0              NaN                                                NaN
# 1   Projeto de Lei  Alteração, Lei de Lavagem de Dinheiro, obrigat...
# 2   Projeto de Lei  Alteração, Lei Geral das Telecomunicações, dis...
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# 5              NaN                                                NaN
# 6   Projeto de Lei  Regulamentação, Constituição Federal, requisit...
# 7              NaN                                                NaN
# 8   Projeto de Lei  Criação, Dia Nacional da Independência do Bras...
# 9   Projeto de Lei  Alteração, Lei Geral das Telecomunicações, dis...
# 10             NaN                                                NaN
# 11             NaN                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ementa                 100 non-null    object
#  1   ementaDetalhada        41 non-null     object
#  2   keywords               100 non-null    object
#  3   uris.uriAutores        100 non-null    object
#  4   uris.uriPropPrincipal  57 non-null     object
#  5   uris.uriUltimoRelator  47 non-null     object
#  6   nome                   100 non-null    object
#  7   cpf                    100 non-null    int64
#  8   foto                   100 non-null    object
#  9   sexo                   100 non-null    object
#  10  nascimento             100 non-null    object
#  11  local_nascimento       100 non-null    object
#  12  escolaridade           98 non-null     object
#  13  ementa_principal       100 non-null    object
#  14  situacao               53 non-null     object
#  15  tipo                   57 non-null     object
#  16  keywords_principal     57 non-null     object
# dtypes: int64(1), object(16)
# memory usage: 13.4+ KB

# %%
foto = pd.concat([df["nome"], df["foto"]], axis=1)
teste = foto.iloc[10:11]
teste["foto"][10]
# Out:
# 'https://www.camara.leg.br/internet/deputado/bandep/220697.jpg'

# %%
df.boxplot()
# Out:
# <Axes: >
